# %%
## Data types
## Numbers= 
  # 1) integers-- Whole Numbers
  # 2) Float-- Numbers with Decimels
  # 3) complex-- Realr + Imaginary

# %%
x=3
y=4.3
z=3+3j

# %%
type(x)
# Out:
# int

# %%
type(y)
# Out:
# float

# %%
type(z)
# Out:
# complex

# %%
## Sring Type (text)
# Text data or sring are enclosed in quotes (' ' or " ")

# %%
name="Shubham"
type(name)
# Out:
# str

# %%
#List
#Tuple
#Range
#Dictionary
#Set

# %%
name="Shubham"
# name= VAriable
#variable is place holder for Our Data

# %% [markdown]
# Rules for create variable
#
# - 1. Sart with a letter or under score
#     ex. name, _age, student1
# - 2. we not ableto create variable which staring with numbers
#
# -3. Varable only contains numbers , Letters, Underscore only
#
#     - We are not allow to use special character as varible
#
# -4. Python is case sensitive
# -5. There are some inbuilt keyword in python they aslo not use as varible
#
#    --ex if,for , while, class, def, return etc

# %%
2name= "Shubham"
# Out:
#   Cell In[102], line 1
#     2name= "Shubham"
#     ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# OPERATIONS
#
# 1. Arithmatic Operations

# %% [markdown]
# - Used For basic mathematic calculations
#
# - + is for addition
# - - for sustraction
# - * for multiplication
# - / for Division
# - // Floar Division
# - % modulus (Gives Whole Number)
# - ** Exponet

# %%
print(10+5)
print(10-5)
print(10*5)
print(10/4)
print(10//4) # gives us Whole Number
print(10%4) #remainder
print(2**3)
# Out:
# 15
# 5
# 50
# 2.5
# 2
# 2
# 8

# %% [markdown]
# #Logical Operators
#
# - Use to Check Multiple Conditions ( True or Flase)
#
# - and , or, not, operators

# %%
# and --> Returns True if Both Conditions Are True

(5>3 and 7<9)
# Out:
# True

# %%
# or --> Return True if any condition is True 

(5>3 or 7>4)
# Out:
# True

# %%
# not--> Reverse the result
not(3>5)
# Out:
# True

# %% [markdown]
# # Asssignment Opertators
# - Used to assign values to variables And can do calculations at same time

# %%
# = Assign Values
x=7
print(x)

# += Add and Assign 
x +=3
print(x)
#or
x=x+4
print(x)

#-= substract and assign

x -= 7
print(x)

# *= Multiply And assign

x*=3
print(x)

# /= Devide and Assign
x /= 7
print(x)

#//= Floar devide and assign

# %= Modulus and assign

# **= Power and assign
# Out:
# 7
# 10
# 14
# 7
# 21
# 3.0

# %% [markdown]
# # Membership Operators
#
# -in --> Return true if value exists
#
# - not in -->  Returns true if value does not exists

# %%
# in 

"b" in "Shubham"
# Out:
# True

# %%
# not in 

"A" not in "sdffghh"
# Out:
# True

# %% [markdown]
# # Identity Operator
#
# - is--> check whether two varibles refer tp the same object( memory location)
#
# - is not--> returns true if there are not common  values in diifrent variable

# %%
# is identity operator
x= 1
y=1 

x is y
# Out:
# True

# %%
#is not identity operator

x=2
y=5

x is not y
# Out:
# True

# %% [markdown]
# # Comparison Operator
#
# ## They Are use to compare Two Variable or Values
#
# - == Equal to
#
# - != Not Equal to
#
# - > Greater Than
#
# - < Lesser Than
#
# - >= Greate Than equal to
#
# - <=  Lesser than Equal to

# %% [markdown]
# # String Data Type
#
# ##String Are use to represent textual data

# %%
institute='Edukron'

focus_area="Data Engineer"

tech_Stack="""Data enginnering and Python"""

# %%
print(type(institute))

print(type(focus_area))

print(type(tech_Stack))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %% [markdown]
# ## Concatination and Repetation
#
# - '+' : Join two string together and creating new string
#
# - '*' : Reapets the string a specified number of time

# %%
# Concatination

# 1. Combining institute and focus area

full_title=institute + focus_area

full_title
# Out:
# 'EdukronData Engineer'

# %%
full_title=institute +" " + focus_area
full_title
# Out:
# 'Edukron Data Engineer'

# %%
age=30
name="shubham"
place="Pune"

# %%
"My Name is name age is age place is place"
# Out:
# 'My Name is name age is age place is place'

# %%
f"My name is {name} age is {age} place is {place} "
# Out:
# 'My name is shubham age is 30 place is Pune '

# %%
# 2. Creating a Course Welcome message

Course_name = "Data Enginner"
welcome_message= "Welcome to" +" "+ institute+ "'s" +" "+ Course_name+" " + "course!"
welcome_message
# Out:
# "Welcome to Edukron's Data Enginner course!"

# %%
print(f"welcome message:{welcome_message}")
# Out:
# welcome message:Welcome to Edukron's Data Enginner course!

# %%
#Repetation
print(institute)
repeted= institute*10
print(repeted)
# Out:
# Edukron
# EdukronEdukronEdukronEdukronEdukronEdukronEdukronEdukronEdukronEdukron

# %%
part1="Learn "
part2="Data science and Data Engineering "
part3="now"

print(f"{part1}{part2}{part3}")
# Out:
# Learn Data science and Data Engineering now

# %% [markdown]
# #Length  len()
#
# - It is inbuilt function that returns the number of character (length) of a srtring

# %%
institute= "Edukron"
course_slogan="Learn Data Engineering with Real-Time Projects"
tech_stack= "Azure DevOps and Python"

# %%
name_length=len(institute)
print(f"Length of '{institute}' : {name_length}")
# Out:
# Length of 'Edukron' : 7

# %%
len(course_slogan)
# Out:
# 46

# %%
len(tech_Stack)
# Out:
# 27

# %% [markdown]
# ## Indexing ([]) ans Slicing([:])
#
# - Indexing : Accesing a single character at a specific position(index)
#
# - There aretwo types of indexing 1. Positive index and 2. Negative index
#
# - positive index start fron count 0(from left side)
#
# - negative index start from -1(from right side)|

# %%
institute= "Edukron"
institute[0]
# Out:
# 'E'

# %%
#Slicing
##Extracting a portion (substring) of the string using [start:stop:step]
    ##start= the index where the slice begins
    ##sotp= The index where the slice ends(exclusive).Default

# %%
tech_stack= "Azure DevOps and Python"

# %%
#Slicing 

# Get first 5 character of tech_stack
#start--> inclusive
#stop--> exclusive

first_5= tech_stack[0:5]
first_5
# Out:
# 'Azure'

# %%
first_5= tech_stack[6:]
first_5
# Out:
# 'DevOps and Python'

# %%
#Get the substring "DevOps"
DevOps= tech_stack[6:12]
DevOps
# Out:
# 'DevOps'

# %%
python_part= tech_stack[-6:]
python_part
# Out:
# 'Python'

# %%
tech_stack[::-1]
# Out:
# 'nohtyP dna spOveD eruzA'

# %% [markdown]
# ### str.lower() and str.upper()
#
# - Lower(): Return With all character convert to lower case.
#
# -Upper(): returns all character to upper case.

# %%
institute='Edukron'

focus_area="Data Engineer"

tech_Stack="Data enginnering and Python"

# %%
## Lower 
lower_institute= institute.lower()
lower_institute
# Out:
# 'edukron'

# %%
upper_institute= institute.upper()
print(upper_institute)

upper_focus=focus_area.upper()
print(upper_focus)

upper_tech_stack=tech_Stack.upper()
upper_tech_stack
# Out:
# EDUKRON
# DATA ENGINEER
# 'DATA ENGINNERING AND PYTHON'

# %%
code="Batch-101-DE"
lower_code= code.lower()
upper_code=code.upper()

print(f"Lowercase:'{lower_code}', Uppercase:'{upper_code}'")
# Out:
# Lowercase:'batch-101-de', Uppercase:'BATCH-101-DE'

# %% [markdown]
# ## str.strip(), str.lstrip() , str.rstrip()
#
# - strip([chars]):Return a new string with leading and trailing spaces are removed.
#
# - lstrip([]): Remove leading char and spaces.
#
# -  rstrip([]): Remove trailing char and spaces.

# %%
strip= "   Shubham   "

# %%
claened_strip=strip.strip()
claened_strip
# Out:
# 'Shubham'

# %%
cleaned_lstrip=strip.lstrip()
cleaned_lstrip
# Out:
# 'Shubham   '

# %%
cleaned_rstrip=strip.rstrip()
cleaned_rstrip
# Out:
# '   Shubham'

# %%
## specific Character removing uusing strip

course_code="===DE001==="
course_code
# Out:
# '===DE001==='

# %%
cleaned_code=course_code.strip("=")
print(cleaned_code) ##bothe side 

cleaned_code=course_code.lstrip("=")
print(cleaned_code) ##only left side

cleaned_code=course_code.rstrip("=")
print(cleaned_code)  ##only right side
# Out:
# DE001
# DE001===
# ===DE001

# %%
path="/courses/Azure/"
clear_path=path.strip("/")
print(clear_path)
# Out:
# courses/Azure

# %%
clear_path=path.strip("/ce")
print(clear_path)
# Out:
# ourses/Azur

# %% [markdown]
# #Replace ==> str.replace(old,new[,count])
#
# -- Return a new string where all occurances of a the substring old are replace with
#     the new substring . If the optional argummets count is given, only the first count occurence is replaced.

# %%
course_slogan="Learn Data Engineering with Real-time Projects"

teck_stack="Azure DevOps and Python and SQL"

# %%
##Replaccing "Data engineering " with "Data Science"

new_slogan= course_slogan.replace("Data Engineering","Data Science")

print(new_slogan)
# Out:
# Learn Data Science with Real-time Projects

# %%
new_slogan=course_slogan.replace("Data Engineering","Data Science").replace("Real-time","Hands-On")
print(new_slogan)
# Out:
# Learn Data Science with Hands-On Projects

# %%
##Replace space with _

new_slogan=course_slogan.replace(" ","_")
print(new_slogan)
# Out:
# Learn_Data_Engineering_with_Real-time_Projects

# %%
new_slogan=course_slogan.replace(" ","_").lower() ##Chaining with lower
print(new_slogan)

new_slogan=course_slogan.replace(" ","_").upper() ##Chaining with Upper
print(new_slogan)

#Chaining= peform 2 or more functions together
# Out:
# learn_data_engineering_with_real-time_projects
# LEARN_DATA_ENGINEERING_WITH_REAL-TIME_PROJECTS

# %%
teck_stack="Azure DevOps and Python and SQL"

##Replace and with & 

replace_tech_stack= teck_stack.replace("and","&")

print(replace_tech_stack)
# Out:
# Azure DevOps & Python & SQL

# %%
##Replace only first and with & 

replace_tech_stack=teck_stack.replace("and","&",1)
print(replace_tech_stack)
# Out:
# Azure DevOps & Python and SQL

# %%
replace_tech_stack=teck_stack.replace("and","&",3)
print(replace_tech_stack)
# Out:
# Azure DevOps & Python & SQL

# %%
course_slogan="Learn Data Engineering with Real-time Projects"

## By usinng replace remove all space 

Space_replace=course_slogan.replace(" ","")

print(Space_replace)
# Out:
# LearnDataEngineeringwithReal-timeProjects

# %%
## REplacing  character which does not exist

not_exist=teck_stack.replace("Machine","shubham")
print(not_exist)
# Out:
# Azure DevOps and Python and SQL

# %%
file_name= "project report final.docx"
##replacce space with _ and .docx with .pdf

new_file= file_name.replace(" ","_").replace(".docx",".pdf")

print(new_file)
# Out:
# project_report_final.pdf

# %%
file_name= "project report final.docx"
##replacing using count=0(nothing is chane it keep data as it is)

new_file= file_name.replace(" ","_",0).replace(".docx",".pdf",0)

print(new_file)
# Out:
# project report final.docx

# %% [markdown]
# #Split
#
# -- str.split(seprater=none, maxsplit= -1).
#
# - Return a list of substring by spliting the string at occurance of the separator.
#
# - if sep is omittedd or none, splis by any whitespace character and discard empty srings.
#
# - if sep is specified , splits at the seperator.
#
# - maxsplit : if specified, perform at most maxsplit splits.

# %%
course_slogan="Learn Data Engineering with Real-time Projects"

teck_stack="Azure DevOps and Python and SQL"

institute= "Edukron"

# %%
split_slogan=course_slogan.split()

print(split_slogan)
# Out:
# ['Learn', 'Data', 'Engineering', 'with', 'Real-time', 'Projects']

# %%
teck_stack="Azure DevOps and Python and SQL"

skills=teck_stack.split()
print(skills)
# Out:
# ['Azure', 'DevOps', 'and', 'Python', 'and', 'SQL']

# %%
institute= "Edukron"

part=institute.split("k")
print(part)
# Out:
# ['Edu', 'ron']

# %%
course_slogan="Learn Data Engineering with Real-time Projects"

split_limit=course_slogan.split(maxsplit=3)

print(split_limit)
# Out:
# ['Learn', 'Data', 'Engineering', 'with Real-time Projects']

# %%
course_slogan="Learn Data Engineering with Real-time Projects"

split_limit=course_slogan.split(" ", maxsplit=3)

print(split_limit)
# Out:
# ['Learn', 'Data', 'Engineering', 'with Real-time Projects']

# %%
path="/data/engineering/"
parts=path.split("/")

print(parts)
# Out:
# ['', 'data', 'engineering', '']

# %% [markdown]
# #Sring Join
#
# - - string.joiniterable
# #### List which we get as output from slipt
#
# -= The opposite of the split . tackes an itrrable (list or tuple) of string and cocanates its elements, using the
#     string on which the method is called as the seperator between elements.

# %%
course_list=["Data Science", "Data Engineering", "Azure DevOps"]  #LIst

tech_skills=("Python", "SQL", "Git", "CI/CD") #Tuple

words= ['Learn', 'Data', 'Engineering'] #List

# %%
join_Course= ", ".join(course_list)
print(join_Course)
# Out:
# Data Science, Data Engineering, Azure DevOps

# %%
join_Course= ", ".join(course_list)
print(f"joined Course : '{join_Course}'")
# Out:
# joined Course : 'Data Science, Data Engineering, Azure DevOps'

# %%
joined_skills="-".join(tech_skills)
joined_skills
# Out:
# 'Python-SQL-Git-CI/CD'

# %%
words= ['Learn', 'Data', 'Engineering']

sentence=" ".join(words)

print(sentence)
# Out:
# Learn Data Engineering

# %% [markdown]
# ## str.startswith(prefix[,start[,end]])
#
# ## str.endswith(suffix[,start[,end]])
#
# -- stsrtswith(): Return true if the string starts with the specified prefix,False otherwise.
#
# --endswith(): Return true if the string endss with the specified suffix,False otherwise.

# %%
institute="Edukron"

course_slogan="Learn Data Engineering with Real-Time Projects"

file_name="edukron_report.pdf"

# %%
## Check institute start with Edu
start_edu=institute.startswith("Edu")
start_edu
# Out:
# True

# %%
## Its a case-sensetive Function
start_edu=institute.startswith("edu")
start_edu
# Out:
# False

# %%
start_edu=institute.startswith("abc")
start_edu
# Out:
# False

# %%
course_slogan="Learn Data Engineering with Real-Time Projects"

#To chek its end with Projects or not

endswith_Projects=course_slogan.endswith("Projects")

endswith_Projects
# Out:
# True

# %%
endswith_Projects=course_slogan.endswith("cts")

endswith_Projects
# Out:
# True

# %%
file_name="edukron_report.pdf"
end_pdf=file_name.endswith("pdf")

end_pdf
# Out:
# True

# %%
file_name="edukron_report.pdf"
end_pdf=file_name.endswith("dcc")

end_pdf
# Out:
# False

# %%
## Check if slogan starts with "Learn" or "Explore"

course_slogan="Learn Data Engineering with Real-Time Projects"

starts_learn_explore=course_slogan.startswith(("Learn","Explore"))

starts_learn_explore
# Out:
# True

# %%
# check a slice: does "Engineering" start at index 11 at slogan ?

course_slogan="Learn Data Engineering with Real-Time Projects"

slice_check_start=course_slogan.startswith("Engineering",11)

slice_check_start
# Out:
# True

# %%
course_slogan="Learn Data Engineering with Real-Time Projects"

slice_check_start=course_slogan.startswith("Engineering",10)

slice_check_start
# Out:
# False

# %%
## check a slice : does "Real-Time" end at index 36>?

slice_check_end=course_slogan.endswith("Real-Time",0,36)

slice_check_end
# Out:
# False

# %% [markdown]
# ### str.find(sub[,start][,end]) and str.index(sbu[,start][,end])
#
# - find(): Searches for the first occurence of subsrting sub with the the string.(or the specified slice).
#    Returns the starting index if find and if not found.
#
#
# - index():  sane as find(), but raises a value if the substring not foun.
#    use find() is you expect the substring might be missing and want to handle it gracefully (-1)
# - use index if you expect the subtring to be present and waant an error if its not.

# %%
course_slogan="Learn Data Engineering with Real-Time Projects"

index_data= course_slogan.find("Data")
index_data
# Out:
# 6

# %%
institute="Edukron"

course_slogan="Learn Data Engineering with Real-Time Projects"

file_name="edukron_report.pdf"
